# %% [markdown]
# # Load corpus PMIDs

# %%
import pandas as pd

# %%
df = pd.read_csv("metadata.csv", index_col=None, header=0, encoding="latin-1")
df = df.dropna(subset=["PMID"])
df["PMID"] = df["PMID"].astype(int)
len(df)
# Out:
# 18155

# %%
pmids = sorted(list(df["PMID"]))
pmids[:3]
# Out:
# [1402966, 1410086, 1448149]

# %% [markdown]
# # Map coordinates to brain atlas structures

# %%
import os
import preproc_coords

# %%
mapped_pmids = [int(file.replace(".txt", "")) for file in os.listdir("../../cogneuro/coordinates/0mm") if not file.startswith(".")]
len(mapped_pmids)
# Out:
# 18169

# %%
pmids_to_map = set(pmids).difference(set(mapped_pmids))
pmids_to_map
# Out:
# set()

# %%
path = "../../cogneuro"
for pmid in pmids_to_map:
    coords = df.loc[df["PMID"] == pmid, "MNI_COORDINATES"].values[0].split(";")
    preproc_coords.run_preproc(path, coords, pmid, smoothing_sigma=0, mask_path=path)

# %% [markdown]
# # Compute document-structure matrix

# %%
def gen_label_bilateral(label):
    
    parts_to_remove = ["juxtapositional_lobule_cortex_(formerly_", ")", "_(includes_h1_and_h2"]
    for part in parts_to_remove:
        label = label.replace(part, "")
    
    return label.strip()

# %%
def prob_thres_dcm(pmids, prob, sigma=0, labs=[], verbose=True,
                   input_path="../", outfile="coordinates.csv"): 

    dcm = {}
    for i, pmid in enumerate(pmids):
        
        if verbose and i % 2000 == 0:
            print("Processing the {}th PMID".format(i))
        
        dcm[pmid] = {}
        dcm[pmid]["PMID"] = int(pmid)
        infile = "{}coordinates/{}mm/{}.txt".format(input_path, sigma, int(pmid))
        lines = open(infile, "r").readlines()
        hits = []
        
        for line in lines:
            for struct in line.split(","):
                if len(struct.split()) == 2:
                    label, p = struct.split()
                    if float(p) > prob:
                        hits += [gen_label_bilateral(label)]
        
        for label in labs:
            count = hits.count(label)
            if count > 0:
                dcm[pmid][label] = 1
            else:
                dcm[pmid][label] = 0
    
    with open(outfile, "w+"):
        out = pd.DataFrame(dcm).transpose()
        out.to_csv(outfile, index=False, quoting=1, columns=["PMID"] + labs)

# %%
lab_df = pd.read_csv("brain/labels_seg.csv")
labs = list(lab_df["PREPROCESSED"])
lab_df.head()
# Out:
#    INDEX                                          TITLE  \
# 0      1                              Left Frontal Pole
# 1      2                            Left Insular Cortex
# 2      3                    Left Superior Frontal Gyrus
# 3      4                      Left Middle Frontal Gyrus
# 4      5  Left Inferior Frontal Gyrus pars triangularis
#
#                                     PREPROCESSED            PRESENTABLE_LOWER  \
# 0                              left_frontal_pole            left frontal pole
# 1                            left_insular_cortex          left insular cortex
# 2                    left_superior_frontal_gyrus  left superior frontal gyrus
# 3                      left_middle_frontal_gyrus    left middle frontal gyrus
# 4  left_inferior_frontal_gyrus_pars_triangularis  left IFG, pars triangularis
#
#                    PRESENTABLE           PRESENTABLE_TITLE ABBREVIATION
# 0            Left Frontal Pole            Frontal pole (L)       FP (L)
# 1          Left Insular Cortex          Insular cortex (L)   Insula (L)
# 2  Left Superior Frontal Gyrus  Superior frontal gyrus (L)      SFG (L)
# 3    Left Middle Frontal Gyrus    Middle frontal gyrus (L)      MFG (L)
# 4  Left IFG, Pars Triangularis  IFG, pars triangularis (L)    trIFG (L)

# %%
prob_thres_dcm(pmids, 0, sigma=0, labs=labs, 
               input_path="../../cogneuro/", outfile="brain/coordinates_seg.csv")
# Out:
# Processing the 0th PMID
# Processing the 2000th PMID
# Processing the 4000th PMID
# Processing the 6000th PMID
# Processing the 8000th PMID
# Processing the 10000th PMID
# Processing the 12000th PMID
# Processing the 14000th PMID
# Processing the 16000th PMID
# Processing the 18000th PMID

# %% [markdown]
# # Check number of coordinates per structure

# %%
act = pd.read_csv("brain/coordinates_seg.csv", index_col=0)
act.head()
# Out:
#          left_frontal_pole  left_insular_cortex  left_superior_frontal_gyrus  \
# PMID
# 1402966                  1                    0                            0
# 1410086                  1                    0                            0
# 1448149                  0                    1                            0
# 1486459                  1                    0                            1
# 1486460                  0                    0                            0
#
#          left_middle_frontal_gyrus  \
# PMID
# 1402966                          0
# 1410086                          1
# 1448149                          0
# 1486459                          1
# 1486460                          0
#
#          left_inferior_frontal_gyrus_pars_triangularis  \
# PMID
# 1402966                                              0
# 1410086                                              1
# 1448149                                              0
# 1486459                                              1
# 1486460                                              0
#
#          left_inferior_frontal_gyrus_pars_opercularis  left_precentral_gyrus  \
# PMID
# 1402966                                             0                      0
# 1410086                                             0                      0
# 1448149                                             0                      0
# 1486459                                             1                      1
# 1486460                                             0                      0
#
#          left_temporal_pole  left_superior_temporal_gyrus_anterior_division  \
# PMID
# 1402966                   0                                               0
# 1410086                   0                                               0
# 1448149                   1                                               0
# 1486459                   1                                               1
# 1486460                   0                                               0
#
#          left_superior_temporal_gyrus_posterior_division  ...  right_crus_i  \
# PMID                                                      ...
# 1402966                                                0  ...             0
# 1410086                                                0  ...             0
# 1448149                                                0  ...             0
# 1486459                                                1  ...             0
# 1486460                                                1  ...             0
#
#          right_crus_ii  right_vermis_crus_i  right_vermis_crus_ii  \
# PMID
# 1402966              0                    0                     0
# 1410086              0                    0                     0
# 1448149              0                    0                     0
# 1486459              0                    0                     0
# 1486460              0                    0                     0
#
#          right_vermis_vi  right_vermis_viib  right_vermis_viiia  \
# PMID
# 1402966                0                  0                   0
# 1410086                0                  0                   0
# 1448149                0                  0                   0
# 1486459                0                  0                   0
# 1486460                0                  0                   0
#
#          right_vermis_viiib  right_vermis_ix  right_vermis_x
# PMID
# 1402966                   0                0               0
# 1410086                   0                0               0
# 1448149                   0                0               0
# 1486459                   0                0               0
# 1486460                   0                0               0
#
# [5 rows x 148 columns]

# %%
for lab in labs:
    print("{:55s}{:5d}".format(lab, sum(act[lab])))
# Out:
# left_frontal_pole                                       9534
# left_insular_cortex                                     6800
# left_superior_frontal_gyrus                             8906
# left_middle_frontal_gyrus                               9852
# left_inferior_frontal_gyrus_pars_triangularis           7138
# left_inferior_frontal_gyrus_pars_opercularis            8096
# left_precentral_gyrus                                  10682
# left_temporal_pole                                      4332
# left_superior_temporal_gyrus_anterior_division          3255
# left_superior_temporal_gyrus_posterior_division         6583
# left_middle_temporal_gyrus_anterior_division            2754
# left_middle_temporal_gyrus_posterior_division           5328
# left_middle_temporal_gyrus_temporooccipital_part        5917
# left_inferior_temporal_gyrus_anterior_division          1502
# left_inferior_temporal_gyrus_posterior_division         3613
# left_inferior_temporal_gyrus_temporooccipital_part      4909
# left_postcentral_gyrus                                  8454
# left_superior_parietal_lobule                           7869
# left_supramarginal_gyrus_anterior_division              7411
# left_supramarginal_gyrus_posterior_division             8926
# left_angular_gyrus                                      8360
# left_lateral_occipital_cortex_superior_division        10328
# left_lateral_occipital_cortex_inferior_division         8062
# left_intracalcarine_cortex                              4207
# left_frontal_medial_cortex                              2953
# left_supplementary_motor_cortex                         5158
# left_subcallosal_cortex                                 1868
# left_paracingulate_gyrus                                7753
# left_cingulate_gyrus_anterior_division                  6930
# left_cingulate_gyrus_posterior_division                 5661
# left_precuneous_cortex                                  7805
# left_cuneal_cortex                                      4195
# left_frontal_orbital_cortex                             7412
# left_parahippocampal_gyrus_anterior_division            3048
# left_parahippocampal_gyrus_posterior_division           3184
# left_lingual_gyrus                                      6417
# left_temporal_fusiform_cortex_anterior_division         1207
# left_temporal_fusiform_cortex_posterior_division        4554
# left_temporal_occipital_fusiform_cortex                 5455
# left_occipital_fusiform_gyrus                           6301
# left_frontal_operculum_cortex                           5732
# left_central_opercular_cortex                           6323
# left_parietal_operculum_cortex                          5461
# left_planum_polare                                      3708
# left_heschls_gyrus                                      3984
# left_planum_temporale                                   5851
# left_supracalcarine_cortex                              3564
# left_occipital_pole                                     5314
# left_thalamus                                           4922
# left_caudate                                            3193
# left_putamen                                            4155
# left_pallidum                                           2566
# left_hippocampus                                        4243
# left_amygdala                                           3040
# left_accumbens                                          1452
# left_brainstem                                          1994
# left_iiv                                                1607
# left_v                                                  2352
# left_vi                                                 3787
# left_viib                                                963
# left_viiia                                               733
# left_viiib                                               456
# left_ix                                                  543
# left_x                                                   224
# left_crus_i                                             3272
# left_crus_ii                                            1574
# left_vermis_crus_i                                       208
# left_vermis_crus_ii                                      210
# left_vermis_vi                                           687
# left_vermis_viib                                         156
# left_vermis_viiia                                        205
# left_vermis_viiib                                        163
# left_vermis_ix                                           208
# left_vermis_x                                             72
# right_frontal_pole                                      9822
# right_insular_cortex                                    6851
# right_superior_frontal_gyrus                            8996
# right_middle_frontal_gyrus                              9270
# right_inferior_frontal_gyrus_pars_triangularis          6674
# right_inferior_frontal_gyrus_pars_opercularis           7370
# right_precentral_gyrus                                 10461
# right_temporal_pole                                     4532
# right_superior_temporal_gyrus_anterior_division         3232
# right_superior_temporal_gyrus_posterior_division        5787
# right_middle_temporal_gyrus_anterior_division           2779
# right_middle_temporal_gyrus_posterior_division          5125
# right_middle_temporal_gyrus_temporooccipital_part       6045
# right_inferior_temporal_gyrus_anterior_division         1269
# right_inferior_temporal_gyrus_posterior_division        2658
# right_inferior_temporal_gyrus_temporooccipital_part     4481
# right_postcentral_gyrus                                 7862
# right_superior_parietal_lobule                          6612
# right_supramarginal_gyrus_anterior_division             5756
# right_supramarginal_gyrus_posterior_division            8558
# right_angular_gyrus                                     8659
# right_lateral_occipital_cortex_superior_division        9517
# right_lateral_occipital_cortex_inferior_division        7462
# right_intracalcarine_cortex                             4480
# right_frontal_medial_cortex                             3002
# right_supplementary_motor_cortex                        5222
# right_subcallosal_cortex                                1852
# right_paracingulate_gyrus                               8493
# right_cingulate_gyrus_anterior_division                 8117
# right_cingulate_gyrus_posterior_division                5905
# right_precuneous_cortex                                 7592
# right_cuneal_cortex                                     4764
# right_frontal_orbital_cortex                            7333
# right_parahippocampal_gyrus_anterior_division           2779
# right_parahippocampal_gyrus_posterior_division          2527
# right_lingual_gyrus                                     6488
# right_temporal_fusiform_cortex_anterior_division        1118
# right_temporal_fusiform_cortex_posterior_division       3259
# right_temporal_occipital_fusiform_cortex                4995
# right_occipital_fusiform_gyrus                          5893
# right_frontal_operculum_cortex                          5636
# right_central_opercular_cortex                          5467
# right_parietal_operculum_cortex                         4768
# right_planum_polare                                     3769
# right_heschls_gyrus                                     3510
# right_planum_temporale                                  5142
# right_supracalcarine_cortex                             4376
# right_occipital_pole                                    5541
# right_thalamus                                          4727
# right_caudate                                           3411
# right_putamen                                           4103
# right_pallidum                                          2629
# right_hippocampus                                       4030
# right_amygdala                                          2955
# right_accumbens                                         1417
# right_brainstem                                         2214
# right_iiv                                               1683
# right_v                                                 2626
# right_vi                                                3977
# right_viib                                               997
# right_viiia                                              851
# right_viiib                                              592
# right_ix                                                 653
# right_x                                                  208
# right_crus_i                                            3602
# right_crus_ii                                           1938
# right_vermis_crus_i                                      207
# right_vermis_crus_ii                                     322
# right_vermis_vi                                          981
# right_vermis_viib                                        268
# right_vermis_viiia                                       367
# right_vermis_viiib                                       288
# right_vermis_ix                                          293
# right_vermis_x                                           103

# %% [markdown]
# # Plot proportion of documents reporting structures
#
# ## Bar chart

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
font = "../style/Arial Unicode.ttf"
font_sm = mpl.font_manager.FontProperties(fname=font, size=10)
font_md = mpl.font_manager.FontProperties(fname=font, size=12)
font_lg = mpl.font_manager.FontProperties(fname=font, size=14)
mpl.rcParams["axes.linewidth"] = 1.5

# %%
fig, ax = plt.subplots(figsize=(6,24))

x = list(reversed(range(len(act.columns))))
y = act.sum().values / len(act)
ax.barh(x, y, tick_label=lab_df["PRESENTABLE_TITLE"], height=0.75, linewidth=1,
        align="center", color=["gray"]*56 + ["#424242"]*18 + ["gray"]*56 + ["#424242"]*18)

ax.xaxis.set_tick_params(width=1.5, length=5)
ax.yaxis.set_tick_params(width=1.5, length=5)

plt.xlim([0,1])

plt.xticks(fontproperties=font_md)
plt.yticks(fontproperties=font_sm)

plt.xlabel("Proportion of documents reporting coordinates", fontproperties=font_lg)

for side in ["right", "top"]:
    ax.spines[side].set_visible(False)
      
plt.margins(y=0)

plt.savefig("figures/seg/proportion_bar.png", dpi=250, bbox_inches="tight")
plt.show()

# %% [markdown]
# ## Brain atlas

# %%
import sys
sys.path.append("..")
import utilities
# %matplotlib inline

# %%
atlas = utilities.load_atlas(cerebellum="seg")
# Out:
# /anaconda3/envs/ontol/lib/python3.6/site-packages/sklearn/externals/joblib/__init__.py:15: DeprecationWarning: sklearn.externals.joblib is deprecated in 0.21 and will be removed in 0.23. Please import this functionality directly from joblib, which can be installed with: pip install joblib. If this warning is raised when loading pickled models, you may need to re-serialize those models with scikit-learn 0.21+.
#   warnings.warn(msg, category=DeprecationWarning)

# %%
data = pd.DataFrame({"proportion": act.sum() / len(act)})
data.head(int(len(act)/2))
# Out:
#                                                     proportion
# left_frontal_pole                                     0.525145
# left_insular_cortex                                   0.374552
# left_superior_frontal_gyrus                           0.490554
# left_middle_frontal_gyrus                             0.542660
# left_inferior_frontal_gyrus_pars_triangularis         0.393170
# left_inferior_frontal_gyrus_pars_opercularis          0.445938
# left_precentral_gyrus                                 0.588378
# left_temporal_pole                                    0.238612
# left_superior_temporal_gyrus_anterior_division        0.179289
# left_superior_temporal_gyrus_posterior_division       0.362600
# left_middle_temporal_gyrus_anterior_division          0.151694
# left_middle_temporal_gyrus_posterior_division         0.293473
# left_middle_temporal_gyrus_temporooccipital_part      0.325916
# left_inferior_temporal_gyrus_anterior_division        0.082732
# left_inferior_temporal_gyrus_posterior_division       0.199009
# left_inferior_temporal_gyrus_temporooccipital_part    0.270394
# left_postcentral_gyrus                                0.465657
# left_superior_parietal_lobule                         0.433434
# left_supramarginal_gyrus_anterior_division            0.408207
# left_supramarginal_gyrus_posterior_division           0.491655
# left_angular_gyrus                                    0.460479
# left_lateral_occipital_cortex_superior_division       0.568879
# left_lateral_occipital_cortex_inferior_division       0.444065
# left_intracalcarine_cortex                            0.231727
# left_frontal_medial_cortex                            0.162655
# left_supplementary_motor_cortex                       0.284109
# left_subcallosal_cortex                               0.102892
# left_paracingulate_gyrus                              0.427045
# left_cingulate_gyrus_anterior_division                0.381713
# left_cingulate_gyrus_posterior_division               0.311815
# ...                                                        ...
# right_heschls_gyrus                                   0.193335
# right_planum_temporale                                0.283228
# right_supracalcarine_cortex                           0.241036
# right_occipital_pole                                  0.305205
# right_thalamus                                        0.260369
# right_caudate                                         0.187882
# right_putamen                                         0.225998
# right_pallidum                                        0.144809
# right_hippocampus                                     0.221977
# right_amygdala                                        0.162765
# right_accumbens                                       0.078050
# right_brainstem                                       0.121950
# right_iiv                                             0.092702
# right_v                                               0.144643
# right_vi                                              0.219058
# right_viib                                            0.054916
# right_viiia                                           0.046874
# right_viiib                                           0.032608
# right_ix                                              0.035968
# right_x                                               0.011457
# right_crus_i                                          0.198403
# right_crus_ii                                         0.106747
# right_vermis_crus_i                                   0.011402
# right_vermis_crus_ii                                  0.017736
# right_vermis_vi                                       0.054035
# right_vermis_viib                                     0.014762
# right_vermis_viiia                                    0.020215
# right_vermis_viiib                                    0.015863
# right_vermis_ix                                       0.016139
# right_vermis_x                                        0.005673
#
# [148 rows x 1 columns]

# %%
for plane in ["x", "y", "z", "ortho"]:
    utilities.map_plane(data, atlas, "figures/seg", suffix="_" + plane, plane=plane, 
                        cmaps=["YlOrRd"], cbar=True, vmin=0.0, vmax=0.6,
                        verbose=False, print_fig=True, annotate=False)
# Out:
# proportion
# proportion
# proportion
# proportion
